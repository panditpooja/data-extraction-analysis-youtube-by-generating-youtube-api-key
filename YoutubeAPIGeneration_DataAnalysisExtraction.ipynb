# %% [markdown]
# # Data extraction and analysis from social media platform Youtube.

# %% [markdown]
# **Steps to be performed**: I have performed few operations to get hands-on and learning purposes.

# %% [markdown]
# 1. Connect to the Youtube API using a Python client

# %% [markdown]
# > 1.a Create a YouTube API key

# %% [markdown]
# > 1.b Install the Google API python client

# %% [markdown]
# refer to the [supporting](https://developers.google.com/youtube/v3/getting-started) link on how to create YouTube API Key

# %% [markdown]
# Reference link : https://developers.google.com/youtube/v3/quickstart/python

# %%
# 1a 
api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = 'API_KEY' #Enter the generated Youtube API key here

# %%
#1b
! pip install google-api-python-client
# Out:
# Collecting google-api-python-client
#   Obtaining dependency information for google-api-python-client from https://files.pythonhosted.org/packages/15/ef/e5515c6eab9eb5dda9b33ec17b8d43c1e71eb063642f5684bbfc4ddc038d/google_api_python_client-2.117.0-py2.py3-none-any.whl.metadata
#   Using cached google_api_python_client-2.117.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in c:\users\dell\anaconda3\lib\site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in c:\users\dell\anaconda3\lib\site-packages (from google-api-python-client) (2.27.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in c:\users\dell\anaconda3\lib\site-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\dell\anaconda3\lib\site-packages (from google-api-python-client) (2.17.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\dell\anaconda3\lib\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\dell\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.62.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in c:\users\dell\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.25.2)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\dell\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dell\anaconda3\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dell\anaconda3\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\dell\anaconda3\lib\site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\dell\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2023.11.17)
# Using cached google_api_python_client-2.117.0-py2.py3-none-any.whl (12.0 MB)
# Installing collected packages: google-api-python-client
# Successfully installed google-api-python-client-2.117.0

# %% [markdown]
# 2. Search and extract the data

# %% [markdown]
# > 2.a Search videos related to the query string  “avatar movie”
# (For this part, choose/search one video of your choice and perform data collection steps on that specific video )
#
# > Output expected : ID, Snippet with following attributes Channel ID, Video Description, Channel Title, Video Title

# %% [markdown]
# Reference link:  https://developers.google.com/youtube/v3/docs/search/list

# %%
#2a
import googleapiclient.discovery as gd
from pprint import pprint as pp
youtube = gd.build(
        api_service_name, api_version, developerKey = DEVELOPER_KEY)
request = youtube.search().list(
        part="id,snippet",
        type='video',
        q="avatar movie",
        maxResults=1,
        fields="items(id(videoId),snippet(channelId,description,channelTitle,title))"
).execute()
pp(request)
# Out:
# {'items': [{'id': {'videoId': 'PLtgIILX7E8'},
#             'snippet': {'channelId': 'UC0A86RKLCqTEUna3hPlEpzg',
#                         'channelTitle': 'Superhero FXL Games',
#                         'description': 'AVATAR Full Movie 2023: Fallen Kingdom '
#                                        '| Superhero FXL Action Movies 2023 in '
#                                        'English (Game Movie). Best Action Game '
#                                        '...',
#                         'title': 'AVATAR Full Movie 2023: Fallen Kingdom | '
#                                  'Superhero FXL Action Movies 2023 in English '
#                                  '(Game Movie)'}}]}

# %%
if request['items']:
    video_id = request['items'][0]['id']['videoId']
    channel_iD = request['items'][0]['snippet']['channelId']
    video_decription = request['items'][0]['snippet']['description']
    video_title = request['items'][0]['snippet']['title']
    channel_title = request['items'][0]['snippet']['channelTitle']
    print("Video ID:", video_id)
    print("Channel ID:", channel_iD)
    print("Video Description:", video_decription)
    print("Channel Title:", channel_title)
    print("Video Title:", video_title)
else:
    print("No video was found.")
# Out:
# Video ID: PLtgIILX7E8
# Channel ID: UC0A86RKLCqTEUna3hPlEpzg
# Video Description: AVATAR Full Movie 2023: Fallen Kingdom | Superhero FXL Action Movies 2023 in English (Game Movie). Best Action Game ...
# Channel Title: Superhero FXL Games
# Video Title: AVATAR Full Movie 2023: Fallen Kingdom | Superhero FXL Action Movies 2023 in English (Game Movie)

# %% [markdown]
# > 2.b  Provide the following statistics for query string “avatar movie” of top 50 videos sorted by relevance in the US region.
#
# > Output expected: video ID, title, no of views, no of likes,no of comments exported to CSV file

# %% [markdown]
# Reference link: https://developers.google.com/youtube/v3/docs/videos/list

# %%
#2b
import pandas as pd
search_response = youtube.search().list(
    type='video',
    q='avatar movie',
    part='id,snippet',
    maxResults=50,
    regionCode='US',
    order='relevance'  # Sort by relevance
).execute()

#Method to get statistics data for each video
video_response_list=[]
def get_video_statistics(video_id):
    video_response = youtube.videos().list(
        part='statistics',
        id=video_id
    ).execute()
    video_response_list.append(video_response)
    for video_result in video_response.get('items', []):
        statistics = video_result['statistics']
        no_of_views = int(statistics.get('viewCount', 0))
        no_of_likes = int(statistics.get('likeCount', 0))
        no_of_comments = int(statistics.get('commentCount', 0))

        return no_of_views, no_of_likes, no_of_comments

#Method to create a list containing video ids,video titles,number of views,number of likes and number of comments
video_data = []
for search_result in search_response.get('items', []):
    video_id = search_result['id']['videoId']
    title = search_result['snippet']['title']
    # Get video statistics
    views, likes, comments = get_video_statistics(video_id)
    video_data.append({
            'video_id': video_id,
            'title': title,
            'Number of views': views,
            'Number of likes': likes,
            'Number of comments': comments
        }) 

# Convert the data to a DataFrame
df = pd.DataFrame(video_data)
df.head(10)
# Out:
#       video_id                                              title  \
# 0  ByAn8DF8Ykk  Avatar: The Last Airbender | Official Trailer ...
# 1  waJKJW_XU90  Avatar: The Last Airbender | Official Teaser |...
# 2  PLtgIILX7E8  AVATAR Full Movie 2023: Fallen Kingdom | Super...
# 3  5PSNL1qE6VY  Avatar | Official Trailer (HD) | 20th Century FOX
# 4  -egQ79OrYCs  THE LAST AIRBENDER (2010) | Hollywood.com Movi...
# 5  3y8a_TFL_KQ  AVATAR Full Movie 2024: The Way of Water | Fin...
# 6  d9MyW72ELq0        Avatar: The Way of Water | Official Trailer
# 7  3G6J-ITWekA  Jake Wakes up in his Avatar Body - AVATAR (4k ...
# 8  l7uZtHJP958  Bạn có biết: Bom tấn Avatar 2 chờ đợi 1 thập k...
# 9  2r71I8lvTIA  The Last Airbender Film: How it Disrespected a...
#
#    Number of views  Number of likes  Number of comments
# 0          6956654           275095               23623
# 1         20176259           459446               41028
# 2         52268071           234694                1773
# 3         12914944            81708                8950
# 4         10660713            22287               11070
# 5          1175021             5023                  66
# 6         58581848          1042388               42982
# 7          5992421            25021                 706
# 8             2759               39                   0
# 9          5207140           156505               27339

# %%
df.shape
# Out:
# (50, 5)

# %%
# Export the DataFrame to a CSV file
df.to_csv('pooja_avatar_movie.csv', index=False)
print("CSV file 'pooja_avatar_movie.csv' created successfully with the each video statistics.")
# Out:
# CSV file 'pooja_avatar_movie.csv' created successfully with the each video statistics.

# %% [markdown]
#  3. Analyze the exported data obtained in 2.b and carry out the following tasks.

# %% [markdown]
# > 3.a Sort the data 2.b  by top 10 comments in descending order and consider the video IDs and Titles of top 10 videos which have highest comments.

# %%
#3a
avatar_movie_df=pd.read_csv('pooja_avatar_movie.csv')
sorted_avatar_movie_dataframe=avatar_movie_df.sort_values(by='Number of comments',ascending=False)

sorted_avatar_movie_dataframe.head(10).reset_index()
# Out:
#    index     video_id                                              title  \
# 0      6  d9MyW72ELq0        Avatar: The Way of Water | Official Trailer
# 1      1  waJKJW_XU90  Avatar: The Last Airbender | Official Teaser |...
# 2      9  2r71I8lvTIA  The Last Airbender Film: How it Disrespected a...
# 3      0  ByAn8DF8Ykk  Avatar: The Last Airbender | Official Trailer ...
# 4     43  MgV9vymLIdQ  The Last Airbender is the Worst Film Ever Made...
# 5      4  -egQ79OrYCs  THE LAST AIRBENDER (2010) | Hollywood.com Movi...
# 6     47  bDHD1ueL4a4  The Weeknd - Nothing Is Lost (You Give Me Stre...
# 7      3  5PSNL1qE6VY  Avatar | Official Trailer (HD) | 20th Century FOX
# 8     49  RGx8rYbRVR4  Why People Hate Avatar: A Lesson In Lazy Comme...
# 9     20  bpI3oxTEd_I  The Secret Airbender in Avatar the Last Airben...
#
#    Number of views  Number of likes  Number of comments
# 0         58581848          1042388               42982
# 1         20176259           459446               41028
# 2          5207140           156505               27339
# 3          6956654           275095               23623
# 4          6217942           116693               14718
# 5         10660713            22287               11070
# 6         29679871           650830                9651
# 7         12914944            81708                8950
# 8           551863            31012                4742
# 9          8879311           754251                3926

# %%
#Considering the video IDs and Titles of top 10 videos which have highest comments.
df_top10_videos=sorted_avatar_movie_dataframe[['video_id', 'title']].head(10)
df_top10_videos
# Out:
#        video_id                                              title
# 6   d9MyW72ELq0        Avatar: The Way of Water | Official Trailer
# 1   waJKJW_XU90  Avatar: The Last Airbender | Official Teaser |...
# 9   2r71I8lvTIA  The Last Airbender Film: How it Disrespected a...
# 0   ByAn8DF8Ykk  Avatar: The Last Airbender | Official Trailer ...
# 43  MgV9vymLIdQ  The Last Airbender is the Worst Film Ever Made...
# 4   -egQ79OrYCs  THE LAST AIRBENDER (2010) | Hollywood.com Movi...
# 47  bDHD1ueL4a4  The Weeknd - Nothing Is Lost (You Give Me Stre...
# 3   5PSNL1qE6VY  Avatar | Official Trailer (HD) | 20th Century FOX
# 49  RGx8rYbRVR4  Why People Hate Avatar: A Lesson In Lazy Comme...
# 20  bpI3oxTEd_I  The Secret Airbender in Avatar the Last Airben...

# %% [markdown]
# > 3.b Use a suitable method to retrieve comments of those top 10 videos from 3.a. For doing this, write a program to loop through each video id from 3.a and pass in the part parameter set to "snippet", to retrieve basic details about the comments. Execute this request and print the response using the pprint() method.

# %%
#3b
# Function to retrieve comments for a video
def get_video_comments(video_id):
    response = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id
    ).execute()
    return response
all_comments_responses=[]
for video_id in df_top10_videos['video_id']:
    response = get_video_comments(video_id)
    all_comments_responses.append(response)
pp(all_comments_responses)
# Out:
# [{'etag': 'X8vEkaOeuZDbwCOmf8tGx3J4N0E',
#   'items': [{'etag': 'Cj81Xe85Xi7dPzCxsNe48pRe5YA',
#              'id': 'UgzJc-jfmGiJRSe5Rz14AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': 'UZgp0i8y8rbCL7fQZ9PsyJ6GodU',
#                                              'id': 'UgzJc-jfmGiJRSe5Rz14AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UCeXQCG7Ykj1RGWs8RjeruLA'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/@LisaLisa-qc8xe',
#                                                          'authorDisplayName': '@LisaLisa-qc8xe',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZQIwuvH_X_uKXUmbrdxhYCPxpLR-P2kFmzoZQ=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                          'likeCount': 1,
#                                                          'publishedAt': '2024-02-10T21:17:48Z',
#                                                          'textDisplay': 'I '
#                                                                         'HAVE '
#                                                                         'TO '
#                                                                         'NOT '
#                                                                         'FINISH    '
#                                                                         'WATCHINGTHIS '
#                                                                         'MOVIE(AVATAR '
#                                                                         '2WAY '
#                                                                         'OF '
#                                                                         'WATER) '
#                                                                         'SO '
#                                                                         'THAT '
#                                                                         'I CAN '
#                                                                         'KEEP '
#                                                                         'THE '
#                                                                         'MEMORIES '
#                                                                         'OF '
#                                                                         'AVATAR '
#                                                                         '1ALIVE<br><br>DIVERT '
#                                                                         'YOUR '
#                                                                         'EYES '
#                                                                         'LOL '
#                                                                         '😂😂😂😂',
#                                                          'textOriginal': 'I '
#                                                                          'HAVE '
#                                                                          'TO '
#                                                                          'NOT '
#                                                                          'FINISH    '
#                                                                          'WATCHINGTHIS '
#                                                                          'MOVIE(AVATAR '
#                                                                          '2WAY '
#                                                                          'OF '
#                                                                          'WATER) '
#                                                                          'SO '
#                                                                          'THAT '
#                                                                          'I '
#                                                                          'CAN '
#                                                                          'KEEP '
#                                                                          'THE '
#                                                                          'MEMORIES '
#                                                                          'OF '
#                                                                          'AVATAR '
#                                                                          '1ALIVE\n'
#                                                                          '\n'
#                                                                          'DIVERT '
#                                                                          'YOUR '
#                                                                          'EYES '
#                                                                          'LOL '
#                                                                          '😂😂😂😂',
#                                                          'updatedAt': '2024-02-10T21:17:48Z',
#                                                          'videoId': 'd9MyW72ELq0',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'd9MyW72ELq0'}},
#             {'etag': 'pyQd1qcZKptIKQMIaVoa1_-como',
#              'id': 'Ugx2xWoxxi1TC79a3954AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': 'JNyJC200_-gxCSV5PVXP4d73U0o',
#                                              'id': 'Ugx2xWoxxi1TC79a3954AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UCFtjaZ4kyrOHCWNHxtW3LZQ'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/@acesaxena7805',
#                                                          'authorDisplayName': '@acesaxena7805',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/oFSO0cbPaPFRRJjAJzfpomFkJOXs-MR0hLoQA6qi10jKVw6IWSLdi9TIn71Inh7e_AKakqxUVA=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                          'likeCount': 0,
#                                                          'publishedAt': '2024-02-09T22:24:41Z',
#                                                          'textDisplay': 'Avatar '
#                                                                         '3 '
#                                                                         'December '
#                                                                         '2025 '
#                                                                         'Avatar '
#                                                                         '4 '
#                                                                         'December '
#                                                                         '2028',
#                                                          'textOriginal': 'Avatar '
#                                                                          '3 '
#                                                                          'December '
#                                                                          '2025 '
#                                                                          'Avatar '
#                                                                          '4 '
#                                                                          'December '
#                                                                          '2028',
#                                                          'updatedAt': '2024-02-09T22:25:02Z',
#                                                          'videoId': 'd9MyW72ELq0',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'd9MyW72ELq0'}},
#             {'etag': 'bJ4KIdiRec-mERPPzFwJScY5SOg',
#              'id': 'UgznmmfiK8a9pOGNVf14AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': '_cyiXDYL4qeckubL1aKnlBaNeRQ',
#                                              'id': 'UgznmmfiK8a9pOGNVf14AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UC59GRUoJK0KiQ2B-gSPViWw'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/@ambitious3164',
#                                                          'authorDisplayName': '@ambitious3164',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/m6FafV5RCUUAjsqsQLEdB79ZpJ8YijyQjnBKDQJn9SToocnie63cvtJ5TEfqTgilN_BXerhokg=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                          'likeCount': 1,
#                                                          'publishedAt': '2024-02-01T03:49:55Z',
#                                                          'textDisplay': 'What '
#                                                                         'a '
#                                                                         'movie. '
#                                                                         'I '
#                                                                         'never '
#                                                                         'experienced '
#                                                                         'like '
#                                                                         'this '
#                                                                         '❤',
#                                                          'textOriginal': 'What '
#                                                                          'a '
#                                                                          'movie. '
#                                                                          'I '
#                                                                          'never '
#                                                                          'experienced '
#                                                                          'like '
#                                                                          'this '
#                                                                          '❤',
#                                                          'updatedAt': '2024-02-01T03:49:55Z',
#                                                          'videoId': 'd9MyW72ELq0',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'd9MyW72ELq0'}},
#             {'etag': 'QZm2x9DhTy6utB-OrF6pCNIsKLQ',
#              'id': 'UgyOplRc_r-MNxlOaZN4AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': 'rtqb4bVp23qa1qmlix1b1JA8GEw',
#                                              'id': 'UgyOplRc_r-MNxlOaZN4AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UCHEC3-rlQs4elJtityE38rQ'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/@XeniusChannel',
#                                                          'authorDisplayName': '@XeniusChannel',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/CspRehnSOUWdwzcd6npvHm4ypJEAYuGNPdxUfsts1VrbDjR5zTFwi_QB6vnFad2i6kegQZ3SGA=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                          'likeCount': 1,
#                                                          'publishedAt': '2024-01-31T00:35:40Z',
#                                                          'textDisplay': '<a '
#                                                                         'href="https://www.youtube.com/watch?v=d9MyW72ELq0&amp;t=120">2:00</a>  '
#                                                                         'I '
#                                                                         'NEED '
#                                                                         'YOU '
#                                                                         'TO BE '
#                                                                         'STRONG....!!!!!   '
#                                                                         '<a '
#                                                                         'href="https://www.youtube.com/watch?v=d9MyW72ELq0&amp;t=129">2:09</a> '
#                                                                         'STRONG '
#                                                                         'HEART.. '
#                                                                         '😱<br>His '
#                                                                         'wife:  '
#                                                                         '<a '
#                                                                         'href="https://www.youtube.com/watch?v=d9MyW72ELq0&amp;t=132">2:12</a> '
#                                                                         '😐',
#                                                          'textOriginal': '2:00  '
#                                                                          'I '
#                                                                          'NEED '
#                                                                          'YOU '
#                                                                          'TO '
#                                                                          'BE '
#                                                                          'STRONG....!!!!!   '
#                                                                          '2:09 '
#                                                                          'STRONG '
#                                                                          'HEART.. '
#                                                                          '😱\n'
#                                                                          'His '
#                                                                          'wife:  '
#                                                                          '2:12 '
#                                                                          '😐',
#                                                          'updatedAt': '2024-01-31T00:37:04Z',
#                                                          'videoId': 'd9MyW72ELq0',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'd9MyW72ELq0'}},
#             {'etag': 'JYkkmI8JRzIi-uYZsv7rDJZvroQ',
#              'id': 'UgxhDRYo5xgEQjtMszp4AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': 'GnfJ7FhSd6KmMyuciAIBj_47TkY',
#                                              'id': 'UgxhDRYo5xgEQjtMszp4AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UCZZRl-rH3MAvokvyr2T1OSQ'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/@pintukhura3349',
#                                                          'authorDisplayName': '@pintukhura3349',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZS8T8_3VlxUDGvrXcQOnAyD7zxj3HqfY4_MaOA8_Dd0z45FTqUP67l_zaIDs_Jx=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                          'likeCount': 3,
#                                                          'publishedAt': '2024-01-30T16:03:04Z',
#                                                          'textDisplay': '2024 '
#                                                                         'batch '
#                                                                         'attendance '
#                                                                         '🤚',
#                                                          'textOriginal': '2024 '
#                                                                          'batch '
#                                                                          'attendance '
#                                                                          '🤚',
#                                                          'updatedAt': '2024-01-30T16:03:04Z',
#                                                          'videoId': 'd9MyW72ELq0',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'd9MyW72ELq0'}},
#             {'etag': '6trmoDUGZQ_1QZSYHfK62KRv48c',
#              'id': 'Ugwi3U45-H1g3sWTuSp4AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': '__5BwuKyU4V_TX731_nmJBA0Zh4',
#                                              'id': 'Ugwi3U45-H1g3sWTuSp4AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UCUhxe5alacVevQwYGAzXSKQ'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/@user-ml8um8ux5m',
#                                                          'authorDisplayName': '@user-ml8um8ux5m',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZRTw9NNlis9SKgnsQ2QaBIc8Ru60fXHR_xginIMQNoUavtCwFQyC3ywudCvOEuh=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                          'likeCount': 2,
#                                                          'publishedAt': '2024-01-27T05:11:47Z',
#                                                          'textDisplay': 'the '
#                                                                         '3d is '
#                                                                         'perfect',
#                                                          'textOriginal': 'the '
#                                                                          '3d '
#                                                                          'is '
#                                                                          'perfect',
#                                                          'updatedAt': '2024-01-27T05:11:47Z',
#                                                          'videoId': 'd9MyW72ELq0',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'd9MyW72ELq0'}},
#             {'etag': 'hlBj6fHgHD8MidjTNfRumYsYeT4',
#              'id': 'UgxHHxyX_Bo5avwhSs94AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': 'ifbqViVgR1qgRcJ4rK1x-62BVZs',
#                                              'id': 'UgxHHxyX_Bo5avwhSs94AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UCwg33N9HaeAVS02ttE-IzEA'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/@cinorikese5890',
#                                                          'authorDisplayName': '@cinorikese5890',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/SmgYtirFXpiygo-qKPMtCF577DC_rNg6yeXCO8TVd_SDdbo6Stv28LSCYAym1Nf5nCfRFAMK=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                          'likeCount': 1,
#                                                          'publishedAt': '2024-01-26T21:14:33Z',
#                                                          'textDisplay': 'the '
#                                                                         'film '
#                                                                         'was '
#                                                                         'shit '
#                                                                         'compared '
#                                                                         'to '
#                                                                         'the '
#                                                                         'first '
#                                                                         'one',
#                                                          'textOriginal': 'the '
#                                                                          'film '
#                                                                          'was '
#                                                                          'shit '
#                                                                          'compared '
#                                                                          'to '
#                                                                          'the '
#                                                                          'first '
#                                                                          'one',
#                                                          'updatedAt': '2024-01-26T21:14:33Z',
#                                                          'videoId': 'd9MyW72ELq0',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 1,
#                          'videoId': 'd9MyW72ELq0'}},
#             {'etag': 'QwHC8S2wXmC0YYgNtm-XxcJdrsw',
#              'id': 'UgxGitT6aGM3tgMi3vl4AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': 'Z-FCLuAazzNCdKuTPz2XdfCuGhc',
#                                              'id': 'UgxGitT6aGM3tgMi3vl4AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UCkEKdLWrZMS1kuKShKEHL7g'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/@afdashtech5322',
#                                                          'authorDisplayName': '@afdashtech5322',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/QjaoBIF1kxHXfhjta8hNPRZcq-z70teMXuW_OOYX7XugwlppIz1ZIXwoGkfrnfAty32UE_BUFNA=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                          'likeCount': 2,
#                                                          'publishedAt': '2024-01-25T06:50:34Z',
#                                                          'textDisplay': 'Very '
#                                                                         'good '
#                                                                         'movie❤',
#                                                          'textOriginal': 'Very '
#                                                                          'good '
#                                                                          'movie❤',
#                                                          'updatedAt': '2024-01-25T06:50:34Z',
#                                                          'videoId': 'd9MyW72ELq0',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'd9MyW72ELq0'}},
#             {'etag': 'imj_H77lz1qJ-cDY2RIKhOS3PJ4',
#              'id': 'UgzA70mQ5A3U-MJ0LfV4AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': '0M81dWk2lUsV_2Y0ayoSNLoctFk',
#                                              'id': 'UgzA70mQ5A3U-MJ0LfV4AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UCohK1hx5gD3OG_YtnUWHz6A'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/@strop100',
#                                                          'authorDisplayName': '@strop100',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZQlqGbyj2dvU7YcdLQQgQATpGy41UpR-KTIGmnX=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                          'likeCount': 2,
#                                                          'publishedAt': '2024-01-19T10:10:31Z',
#                                                          'textDisplay': 'Фильм '
#                                                                         '- '
#                                                                         'говно...С '
#                                                                         'первым '
#                                                                         'фильмом '
#                                                                         'никакого '
#                                                                         'сравнения...',
#                                                          'textOriginal': 'Фильм '
#                                                                          '- '
#                                                                          'говно...С '
#                                                                          'первым '
#                                                                          'фильмом '
#                                                                          'никакого '
#                                                                          'сравнения...',
#                                                          'updatedAt': '2024-01-19T10:10:31Z',
#                                                          'videoId': 'd9MyW72ELq0',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'd9MyW72ELq0'}},
#             {'etag': 'J0HoS30RBr7DT8vbqKjtds5z5Dg',
#              'id': 'UgwSQyjdtZAfQre0b7F4AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': 'DV2nM3BHZOBhARyJ3SkKVlZxFRM',
#                                              'id': 'UgwSQyjdtZAfQre0b7F4AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UCMi9zxFCqLt9rmHZ9vIxIFg'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/@carlyannweller',
#                                                          'authorDisplayName': '@carlyannweller',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZQzz4oEZXcjzcSSzTad5lTLvBIF-mYJ_yYjQH-qyg=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                          'likeCount': 1,
#                                                          'publishedAt': '2024-01-19T09:48:37Z',
#                                                          'textDisplay': 'What '
#                                                                         'an '
#                                                                         'amazing '
#                                                                         'movie! '
#                                                                         'After '
#                                                                         'seeing '
#                                                                         'trailer '
#                                                                         'I’m '
#                                                                         'like '
#                                                                         'eh '
#                                                                         'not '
#                                                                         'going '
#                                                                         'to be '
#                                                                         'as '
#                                                                         'good '
#                                                                         'as '
#                                                                         'first. '
#                                                                         'But '
#                                                                         'the '
#                                                                         'love '
#                                                                         'for '
#                                                                         'family '
#                                                                         'was '
#                                                                         'amazing!  '
#                                                                         'I '
#                                                                         'cried '
#                                                                         'alittle '
#                                                                         ':)',
#                                                          'textOriginal': 'What '
#                                                                          'an '
#                                                                          'amazing '
#                                                                          'movie! '
#                                                                          'After '
#                                                                          'seeing '
#                                                                          'trailer '
#                                                                          'I’m '
#                                                                          'like '
#                                                                          'eh '
#                                                                          'not '
#                                                                          'going '
#                                                                          'to '
#                                                                          'be '
#                                                                          'as '
#                                                                          'good '
#                                                                          'as '
#                                                                          'first. '
#                                                                          'But '
#                                                                          'the '
#                                                                          'love '
#                                                                          'for '
#                                                                          'family '
#                                                                          'was '
#                                                                          'amazing!  '
#                                                                          'I '
#                                                                          'cried '
#                                                                          'alittle '
#                                                                          ':)',
#                                                          'updatedAt': '2024-01-19T09:48:37Z',
#                                                          'videoId': 'd9MyW72ELq0',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'd9MyW72ELq0'}},
#             {'etag': '4geoUqc5qxLXuyNW_qpyPm7QFjU',
#              'id': 'UgyOYqpnAHY2UmSkOBB4AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': 'mbZB-xCwIJZDjIjhCmCYYpEVhOA',
#                                              'id': 'UgyOYqpnAHY2UmSkOBB4AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UCDR14VaDyGnzeogOOPwRlEg'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/@hemalatalokeshkushawah9718',
#                                                          'authorDisplayName': '@hemalatalokeshkushawah9718',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/sQxWpOPAI65_RMReUCAZmKuw0Xdho-RXM1kVxUH7tPqBVs10jntg25I0CCybkeqB-N7ZtHBPF94=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                          'likeCount': 1,
#                                                          'publishedAt': '2024-01-18T16:21:48Z',
#                                                          'textDisplay': 'I m '
#                                                                         'live '
#                                                                         'in '
#                                                                         'watch '
#                                                                         'avataarv3....weak '
#                                                                         'English',
#                                                          'textOriginal': 'I m '
#                                                                          'live '
#                                                                          'in '
#                                                                          'watch '
#                                                                          'avataarv3....weak '
#                                                                          'English',
#                                                          'updatedAt': '2024-01-18T16:22:45Z',
#                                                          'videoId': 'd9MyW72ELq0',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'd9MyW72ELq0'}},
#             {'etag': '5Dyf_aTMx7I92jLB-QlYQRY44aU',
#              'id': 'UgzRg3zMhifoV2rhkC94AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': '8zAUVzoBd37DCF2j0wv7IumZ--Q',
#                                              'id': 'UgzRg3zMhifoV2rhkC94AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UC3iUCsX6UuygOzoahRjbENQ'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/@Abc123z1000',
#                                                          'authorDisplayName': '@Abc123z1000',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZRbtc_8zn8FtlkQPJVctZHUmhgrTz-h4EeUBCcj=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                          'likeCount': 1,
#                                                          'publishedAt': '2024-01-15T23:21:35Z',
#                                                          'textDisplay': 'Shiiiiiiiit, '
#                                                                         'one '
#                                                                         'of my '
#                                                                         'friends '
#                                                                         'saw '
#                                                                         'this '
#                                                                         'movie '
#                                                                         'and '
#                                                                         'said '
#                                                                         'it '
#                                                                         'was '
#                                                                         '&quot;meh&quot; '
#                                                                         'and '
#                                                                         '&quot;okay&quot;. '
#                                                                         'But '
#                                                                         'now, '
#                                                                         'looking '
#                                                                         'at '
#                                                                         'the '
#                                                                         'trailer, '
#                                                                         'it '
#                                                                         'gave '
#                                                                         'me '
#                                                                         'GOOSEBUMPS. '
#                                                                         'I '
#                                                                         'need '
#                                                                         'to '
#                                                                         'find '
#                                                                         'this '
#                                                                         'movie '
#                                                                         'so I '
#                                                                         'can '
#                                                                         'watch '
#                                                                         'it 🤔',
#                                                          'textOriginal': 'Shiiiiiiiit, '
#                                                                          'one '
#                                                                          'of '
#                                                                          'my '
#                                                                          'friends '
#                                                                          'saw '
#                                                                          'this '
#                                                                          'movie '
#                                                                          'and '
#                                                                          'said '
#                                                                          'it '
#                                                                          'was '
#                                                                          '"meh" '
#                                                                          'and '
#                                                                          '"okay". '
#                                                                          'But '
#                                                                          'now, '
#                                                                          'looking '
#                                                                          'at '
#                                                                          'the '
#                                                                          'trailer, '
#                                                                          'it '
#                                                                          'gave '
#                                                                          'me '
#                                                                          'GOOSEBUMPS. '
#                                                                          'I '
#                                                                          'need '
#                                                                          'to '
#                                                                          'find '
#                                                                          'this '
#                                                                          'movie '
#                                                                          'so I '
#                                                                          'can '
#                                                                          'watch '
#                                                                          'it 🤔',
#                                                          'updatedAt': '2024-01-15T23:21:35Z',
#                                                          'videoId': 'd9MyW72ELq0',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'd9MyW72ELq0'}},
#             {'etag': 'yhzhfL6zeMfZcUmjfBpZhxKNFrg',
#              'id': 'UgwlgNyzl543_KsO9I14AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': 'c4Dvvhp3KrJzwUjB1zbIjOHMbU8',
#                                              'id': 'UgwlgNyzl543_KsO9I14AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UCsM6xQ-kmIrXXobaf69z3KQ'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/@sezden8479',
#                                                          'authorDisplayName': '@sezden8479',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/7l5zFx2v1vTTeuzsG1JTiWdLBeb4ShdSgTjwb_d4ZItD8pYs2vBm7e-8FbDUWBpyaFE2zN3V7Jc=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                          'likeCount': 2,
#                                                          'publishedAt': '2024-01-14T19:07:39Z',
#                                                          'textDisplay': 'Breathless '
#                                                                         'movie, '
#                                                                         'into '
#                                                                         'ALL '
# ...
#                                                                          'his '
#                                                                          'sister, '
#                                                                          'and '
#                                                                          'his '
#                                                                          'father!" '
#                                                                          'As '
#                                                                          'if '
#                                                                          'that '
#                                                                          'whole '
#                                                                          'nation '
#                                                                          'looks '
#                                                                          'like '
#                                                                          'that '
#                                                                          'singular '
#                                                                          'family. '
#                                                                          'Also '
#                                                                          'you '
#                                                                          'may '
#                                                                          'say '
#                                                                          '"well '
#                                                                          'mai '
#                                                                          'isnt" '
#                                                                          'correct, '
#                                                                          'but '
#                                                                          'she '
#                                                                          'is '
#                                                                          'from '
#                                                                          'a '
#                                                                          'royal '
#                                                                          'family. '
#                                                                          'And '
#                                                                          'royal '
#                                                                          'families '
#                                                                          'love '
#                                                                          'getting '
#                                                                          'close '
#                                                                          'and '
#                                                                          'mixing '
#                                                                          'their '
#                                                                          'bloodlines. '
#                                                                          'So '
#                                                                          'its '
#                                                                          'just '
#                                                                          'a '
#                                                                          'weak '
#                                                                          'argument '
#                                                                          'in '
#                                                                          'my '
#                                                                          'opinion.',
#                                                          'updatedAt': '2024-02-08T22:49:11Z',
#                                                          'videoId': 'bpI3oxTEd_I',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'bpI3oxTEd_I'}},
#             {'etag': 'BmeI6wxdDjfFNGoMMjEeV8doRjw',
#              'id': 'UgwasLM4vIkZ-BWGGAN4AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UC3sznuotAs2ohg_U__Jzj_Q',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': '4as5XDaia3HdFLaZ7ybwp9FVd2Q',
#                                              'id': 'UgwasLM4vIkZ-BWGGAN4AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UCG11LTnQAICzLTs-UJrtrmQ'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/@jhezrylgundran2495',
#                                                          'authorDisplayName': '@jhezrylgundran2495',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZSUsHvfSnzK1H3NnPn2Paa3YmZ_EcFVGP4Vfx9KAQ=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UC3sznuotAs2ohg_U__Jzj_Q',
#                                                          'likeCount': 0,
#                                                          'publishedAt': '2024-02-08T18:28:34Z',
#                                                          'textDisplay': 'Ty '
#                                                                         'Lee '
#                                                                         'was '
#                                                                         'and '
#                                                                         'will '
#                                                                         'always '
#                                                                         'be my '
#                                                                         'cartoon '
#                                                                         'crush '
#                                                                         '🥰',
#                                                          'textOriginal': 'Ty '
#                                                                          'Lee '
#                                                                          'was '
#                                                                          'and '
#                                                                          'will '
#                                                                          'always '
#                                                                          'be '
#                                                                          'my '
#                                                                          'cartoon '
#                                                                          'crush '
#                                                                          '🥰',
#                                                          'updatedAt': '2024-02-08T18:28:34Z',
#                                                          'videoId': 'bpI3oxTEd_I',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'bpI3oxTEd_I'}},
#             {'etag': 'YCD2fkia7cbg6d9FkHo5T3HPKg0',
#              'id': 'UgyWeV2BHO_2xSckOBh4AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UC3sznuotAs2ohg_U__Jzj_Q',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': 'baz0asB-mxtWy1JE1EIiSKVoWG8',
#                                              'id': 'UgyWeV2BHO_2xSckOBh4AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UCCou3LuKasQM8I7_o8uOppw'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/@zlatafruhling1948',
#                                                          'authorDisplayName': '@zlatafruhling1948',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZQcqjpvikVrhjUnqS6zawwHuyv-XQSCLpOOmDa0=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UC3sznuotAs2ohg_U__Jzj_Q',
#                                                          'likeCount': 0,
#                                                          'publishedAt': '2024-02-07T23:46:34Z',
#                                                          'textDisplay': 'Where '
#                                                                         'is '
#                                                                         'her '
#                                                                         'eyes '
#                                                                         'are '
#                                                                         'grey? '
#                                                                         'Brown.',
#                                                          'textOriginal': 'Where '
#                                                                          'is '
#                                                                          'her '
#                                                                          'eyes '
#                                                                          'are '
#                                                                          'grey? '
#                                                                          'Brown.',
#                                                          'updatedAt': '2024-02-07T23:46:34Z',
#                                                          'videoId': 'bpI3oxTEd_I',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'bpI3oxTEd_I'}},
#             {'etag': 'XtytZocbRobs8T5DyfN8KuDsRRM',
#              'id': 'UgxDbnTqLkpOTbrG7ad4AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UC3sznuotAs2ohg_U__Jzj_Q',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': 'SmXRYw-EKYLPAGGPHTor3aWnrjA',
#                                              'id': 'UgxDbnTqLkpOTbrG7ad4AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UC62cjlS_vB_RGygjIaOb7PQ'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/@TheDefiniteArticle_',
#                                                          'authorDisplayName': '@TheDefiniteArticle_',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/xUwwjzYnEMXYwIZzBoaeJs6EykCZZnWktH9ju8rW3nkq_W37TSI8adKQiKoG1lBuFQenGVo5tA=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UC3sznuotAs2ohg_U__Jzj_Q',
#                                                          'likeCount': 0,
#                                                          'publishedAt': '2024-02-07T22:03:47Z',
#                                                          'textDisplay': 'Matpat: '
#                                                                         'they '
#                                                                         'basically '
#                                                                         'look '
#                                                                         'the '
#                                                                         'same<br>Me:',
#                                                          'textOriginal': 'Matpat: '
#                                                                          'they '
#                                                                          'basically '
#                                                                          'look '
#                                                                          'the '
#                                                                          'same\n'
#                                                                          'Me:',
#                                                          'updatedAt': '2024-02-07T22:03:47Z',
#                                                          'videoId': 'bpI3oxTEd_I',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'bpI3oxTEd_I'}},
#             {'etag': 'ES6dW_cduHsZ-BH6XIZm8I9rQBk',
#              'id': 'UgxeIM7B70MjN5HK_ox4AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UC3sznuotAs2ohg_U__Jzj_Q',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': 'I9fHoveqJjRnLeZcA6uB_aedwCs',
#                                              'id': 'UgxeIM7B70MjN5HK_ox4AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UC-P155hefIV7ZgEZ_VIGyqA'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/@SirMCraftalot',
#                                                          'authorDisplayName': '@SirMCraftalot',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZQ1-1dfY8_3n3cSA3uTuKTJsJPvuskcVs44L-khwQ=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UC3sznuotAs2ohg_U__Jzj_Q',
#                                                          'likeCount': 1,
#                                                          'publishedAt': '2024-02-07T16:56:46Z',
#                                                          'textDisplay': 'S M A '
#                                                                         'S H',
#                                                          'textOriginal': 'S M '
#                                                                          'A S '
#                                                                          'H',
#                                                          'updatedAt': '2024-02-07T16:56:46Z',
#                                                          'videoId': 'bpI3oxTEd_I',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'bpI3oxTEd_I'}}],
#   'kind': 'youtube#commentThreadListResponse',
#   'nextPageToken': 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNKMGdHQUVTQlFpSElCZ0FFZ1VJcUNBWUFCSUZDSWdnR0FBU0JRaUpJQmdBR0FBaURnb01DTTNzanE0R0VMRDVfUGtC',
#   'pageInfo': {'resultsPerPage': 20, 'totalResults': 20}}]

# %% [markdown]
# > 3.c Write a program to export the output of question 3.b in JSON file format.

# %%
#3c
import json
# Define the filename for the JSON file
output_file = "pooja_avatar_movie_comments.json"

# Write to the json file
with open(output_file, 'w') as f:
    json.dump(all_comments_responses, f)

print(f"Comments successfully exported to '{output_file}'")
# Out:
# Comments successfully exported to 'pooja_avatar_movie_comments.json'

# %% [markdown]
# >3.d Write a function to get  the likes vs views ratio of the top 10 videos obtained in 3.a with the highest comments.

# %%
#3d
import numpy as np
top_10_videos_data=sorted_avatar_movie_dataframe.head(10).copy()
def calculate_likes_views_ratio(top_10_videos_data):
    # Calculate likes vs views ratio for each video
    top_10_videos_data[ 'Likes Views Ratio']= top_10_videos_data['Number of likes'] / top_10_videos_data['Number of views'] 

    # Create a new dataframe with video ID, title, likes, views, and the ratio
    ratio_df = top_10_videos_data[['video_id','title','Number of likes', 'Number of views', 'Likes Views Ratio']].copy()


    return ratio_df
top10_videos_with_likes_views_ratio = calculate_likes_views_ratio(top_10_videos_data)

top10_videos_with_likes_views_ratio['Likes Views Ratio'] = top10_videos_with_likes_views_ratio['Likes Views Ratio'].replace(np.inf, 0)
top10_videos_with_likes_views_ratio.reset_index(drop=True)
# Out:
#       video_id                                              title  \
# 0  d9MyW72ELq0        Avatar: The Way of Water | Official Trailer
# 1  waJKJW_XU90  Avatar: The Last Airbender | Official Teaser |...
# 2  2r71I8lvTIA  The Last Airbender Film: How it Disrespected a...
# 3  ByAn8DF8Ykk  Avatar: The Last Airbender | Official Trailer ...
# 4  MgV9vymLIdQ  The Last Airbender is the Worst Film Ever Made...
# 5  -egQ79OrYCs  THE LAST AIRBENDER (2010) | Hollywood.com Movi...
# 6  bDHD1ueL4a4  The Weeknd - Nothing Is Lost (You Give Me Stre...
# 7  5PSNL1qE6VY  Avatar | Official Trailer (HD) | 20th Century FOX
# 8  RGx8rYbRVR4  Why People Hate Avatar: A Lesson In Lazy Comme...
# 9  bpI3oxTEd_I  The Secret Airbender in Avatar the Last Airben...
#
#    Number of likes  Number of views  Likes Views Ratio
# 0          1042388         58581848           0.017794
# 1           459446         20176259           0.022772
# 2           156505          5207140           0.030056
# 3           275095          6956654           0.039544
# 4           116693          6217942           0.018767
# 5            22287         10660713           0.002091
# 6           650830         29679871           0.021928
# 7            81708         12914944           0.006327
# 8            31012           551863           0.056195
# 9           754251          8879311           0.084945
